# %% [markdown]
# ## 0. Import lists of words generated from the topic modeling notebook

# %%
# %%capture
# Suppress output and run topic modeling notebook
# %run ./topic_modeling.ipynb

# %% [markdown]
# ## 1. Word Cloud for Title

# %%
import os
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import random

#Provided list of words with frequencies after lemmatization (from topic_modeling.ipynb)
word_freqs = {
    'network': 18,
    'neural': 17,
    'base': 15,
    'team': 15,
    'basketball': 12,
    'football': 11,
    'model': 10,
    'data': 10,
    'use': 9,
    'game': 8,
    'prediction': 8,
    'artificial': 8,
    'performance': 8,
    'injury': 7,
    'analysis': 7
}

#Custom color function for varying shades of pink
def pink_color_func(word, font_size, position, orientation, **kwargs):
    colors = ['#AC573D', '#F19E93', '#E8BA5A', '#FF8FAB', '#00433F']
    return random.choice(colors)

#Create a word cloud with varying shades of pink
wordcloud_T = WordCloud(width=800, height=800, 
                      background_color='white',
                      color_func=pink_color_func,
                      random_state=123).generate_from_frequencies(word_freqs)

# Export the image
wordcloud_T.to_file(os.path.join('..','figures','wordcloud_T.png'))

#Display the word cloud using matplotlib
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud_T, interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## 2. Word Cloud for Abstract

# %%
word_freqs_A = {
    'team': 35,
    'data': 27,
    'use': 27,
    'performance': 26,
    'model': 21,
    'classification': 19,
    'match': 19,
    'ball': 18,
    'indicator': 18,
    'classify': 16,
    'analysis': 16,
    'game': 16,
    'outcome': 16,
    'approach': 15,
    'learn': 15
}
wordcloud_A = WordCloud(width=800, height=800, 
                      background_color='white',
                      color_func=pink_color_func,
                      random_state=123).generate_from_frequencies(word_freqs_A)

wordcloud_A.to_file(os.path.join('..','figures','wordcloud_A.png'))

#Display the word cloud using matplotlib
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud_A, interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## 3. Word Cloud for Title and Abstract

# %%
word_freqs_TA = {
    'team': 47,
    'use': 38,
    'performance': 33,
    'base': 30,
    'data': 29,
    'model': 28,
    'network': 24,
    'match': 24,
    'football': 22,
    'neural': 21,
    'classification': 20,
    'analysis': 20,
    'game': 20,
    'indicator': 20,
    'injury': 19
}
wordcloud_TA = WordCloud(width=800, height=800, 
                      background_color='white',
                      color_func=pink_color_func,
                      random_state=123).generate_from_frequencies(word_freqs_TA)

wordcloud_TA.to_file(os.path.join('..','figures','wordcloud_TA.png'))

#Display the word cloud using matplotlib
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud_TA, interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## 4. Word Cloud for Phrases

# %%
ingredients = ['performance indicators', 'team performance', 'neural network',
             'match outcome', 'machine learning', 'data mining', 'artificial neural', 'olympic games', 'neural networks', 'ground reaction',
             'team performance indicators', 'artificial neural network', 'support vector machine', 'one versus one', 'ground reaction force',
             'class errors ranging', 'provided greatest probability']
frequencies = [14, 13, 12, 9, 8, 8, 8, 7, 7, 7, 10, 8, 5, 4, 4, 3, 3]

d = dict(zip(ingredients, frequencies))

wordcloud_phrases = WordCloud(width=800, height=800, 
                      background_color='white',
                      color_func=pink_color_func,
                      random_state=123,
                      collocations=False).generate_from_frequencies(d)

wordcloud_phrases.to_file(os.path.join('..','figures','wordcloud_phrases.png'))

plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud_phrases, interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
